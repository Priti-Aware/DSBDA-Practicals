# %% [markdown]
# ### Name: Priti Balkrushna Aware
# ### Roll No: 07
# ### Class: TE-B
#
# ### Assignment No:01
# ### Data Wrangling I
# Perform the following operations using Python on any open source dataset (e.g., data.csv)
# 1. Import all the required Python Libraries.
# 2. Locate an open source data from the web (e.g., https://www.kaggle.com). Provide a clear
#  description of the data and its source (i.e., URL of the web site).
# 3. Load the Dataset into pandas dataframe.
# 4. Data Preprocessing: check for missing values in the data using pandas isnull(), describe()
# function to get some initial statistics. Provide variable descriptions. Types of variables etc.
# Check the dimensions of the data frame.
# 5. Data Formatting and Data Normalization: Summarize the types of variables by checking
# the data types (i.e., character, numeric, integer, factor, and logical) of the variables in the
# data set. If variables are not in the correct data type, apply proper type conversions.
# 6. Turn categorical variables into quantitative variables in Python.

# %%
import pandas as pd # 1.Import all the required Python Libraries.

# %%
df=pd.read_csv("Iris.csv")   #3.Load the Dataset into pandas dataframe.

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.isnull()  #4.check availability of null value
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df.describe()  #4.display statistics
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.size #check count of data element
# Out:
# 900

# %%
df.ndim  #To check dimension
# Out:
# 2

# %%
df.shape  # to count number of rows and columns
# Out:
# (150, 6)

# %%
df.info()  #to check datatype of every variable
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df['SepalLengthCm']= df['SepalLengthCm'].astype(int)  #5.Data Formatting and Data Normalization means changing datatype of data elements
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1              5           3.5            1.4           0.2
# 1      2              4           3.0            1.4           0.2
# 2      3              4           3.2            1.3           0.2
# 3      4              4           3.1            1.5           0.2
# 4      5              5           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146              6           3.0            5.2           2.3
# 146  147              6           2.5            5.0           1.9
# 147  148              6           3.0            5.2           2.0
# 148  149              6           3.4            5.4           2.3
# 149  150              5           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['Species'].replace({"Iris-setosa":0,"Iris-virginica":1})
df # 6.Turn categorical variables into quantitative variables
#, inplace=True   is used to make changes in current original available dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0      1              5           3.5            1.4           0.2       0
# 1      2              4           3.0            1.4           0.2       0
# 2      3              4           3.2            1.3           0.2       0
# 3      4              4           3.1            1.5           0.2       0
# 4      5              5           3.6            1.4           0.2       0
# ..   ...            ...           ...            ...           ...     ...
# 145  146              6           3.0            5.2           2.3       1
# 146  147              6           2.5            5.0           1.9       1
# 147  148              6           3.0            5.2           2.0       1
# 148  149              6           3.4            5.4           2.3       1
# 149  150              5           3.0            5.1           1.8       1
#
# [150 rows x 6 columns]

# %%
df.dropna() #To drop null value
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1              5           3.5            1.4           0.2
# 1      2              4           3.0            1.4           0.2
# 2      3              4           3.2            1.3           0.2
# 3      4              4           3.1            1.5           0.2
# 4      5              5           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146              6           3.0            5.2           2.3
# 146  147              6           2.5            5.0           1.9
# 147  148              6           3.0            5.2           2.0
# 148  149              6           3.4            5.4           2.3
# 149  150              5           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X=df.iloc[:,:4]
X
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0      1            5.1           3.5            1.4
# 1      2            4.9           3.0            1.4
# 2      3            4.7           3.2            1.3
# 3      4            4.6           3.1            1.5
# 4      5            5.0           3.6            1.4
# ..   ...            ...           ...            ...
# 145  146            6.7           3.0            5.2
# 146  147            6.3           2.5            5.0
# 147  148            6.5           3.0            5.2
# 148  149            6.2           3.4            5.4
# 149  150            5.9           3.0            5.1
#
# [150 rows x 4 columns]

# %%
X_scaled = min_max_scaler.fit_transform(X)
df_normalized = pd.DataFrame(X_scaled)
df_normalized
# Out:
#             0         1         2         3
# 0    0.000000  0.222222  0.625000  0.067797
# 1    0.006711  0.166667  0.416667  0.067797
# 2    0.013423  0.111111  0.500000  0.050847
# 3    0.020134  0.083333  0.458333  0.084746
# 4    0.026846  0.194444  0.666667  0.067797
# ..        ...       ...       ...       ...
# 145  0.973154  0.666667  0.416667  0.711864
# 146  0.979866  0.555556  0.208333  0.677966
# 147  0.986577  0.611111  0.416667  0.711864
# 148  0.993289  0.527778  0.583333  0.745763
# 149  1.000000  0.444444  0.416667  0.694915
#
# [150 rows x 4 columns]
