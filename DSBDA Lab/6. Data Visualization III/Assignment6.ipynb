# %% [markdown]
# ### Name: Priti Balkrushna Aware
# ### Roll No: 07
# ### Class: TE-B
#
# ### Assignment No:06
# ### Data Visualization III
#
# Download the Iris flower dataset or any other dataset into a DataFrame. (e.g.,
# https://archive.ics.uci.edu/ml/datasets/Iris ). Scan the dataset and give the inference as:
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# 3. Create a boxplot for each feature in the dataset.
# 4. Compare distributions and identify outliers.gram.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Step 2: List down features and their types
print("\nFeatures and Types:")
print(df.dtypes)
# Out:
# Features and Types:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# Step 3: Create histograms for each feature
df.hist(figsize=(10, 8))
plt.suptitle('Histograms of Iris Dataset Features', y=1.02)
plt.show()

# %%
df.hist("SepalLengthCm")
df.hist("SepalWidthCm")
df.hist("PetalWidthCm")
df.hist("PetalLengthCm")
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}>]], dtype=object)

# %%
# Step 4: Create boxplots for each feature
df.boxplot(figsize=(10, 8))
plt.title('Boxplots of Iris Dataset Features')
plt.show()

# %%
# Comparing Distributions and Identifying Outliers
# We'll visually compare the distributions of each feature using histograms and boxplots.
# Outliers can be identified as data points lying significantly outside the whiskers of the boxplots.

# To identify outliers from the boxplot output, look for data points that lie significantly outside the whiskers of the boxplots. In a boxplot:

# Points beyond the ends of the whiskers are considered potential outliers.
# Whiskers typically extend to 1.5 times the interquartile range (IQR) from the first and third quartiles (the box boundaries).
# Data points beyond the whiskers are often marked as individual points or dots.
# Let's identify potential outliers from the boxplot output of the Iris dataset:

# Look for any individual points outside the whiskers of the boxplots for each feature.
# These points may indicate potential outliers in the dataset.
# You can visually inspect the boxplots for each feature and observe any points that lie far away from the box boundaries (whiskers). These points may represent outliers in the dataset.
